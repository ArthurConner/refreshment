# %%
# default_exp School

# %%
# %load_ext autoreload
# %autoreload 2

# %matplotlib inline

# %% [markdown]
# # School Model
#
# > API details.

# %%
#export
import os
import sys
import json

# %%
#hide
from nbdev.showdoc import *
cPath = os.path.dirname(os.getcwd())
sys.path.insert(0,cPath)

# %%
#export
from os import listdir,  walk
from os.path import isfile, join, getmtime
from collections import deque, Counter
from refreshment.Program import Program, Subject, Record, Lesson
import re

# %%
#export
def fullPathSplit(x):
    ret = deque()
    done = False
    while not done:
        (remain, file) = os.path.split(x)
        ret.appendleft(file)
        done = (x == remain)
        x = remain
    return ret

# %%
#hide
fullPathSplit("../../Cathedral/Mindful")
# Out:
# deque(['', '..', '..', 'Cathedral', 'Mindful'])

# %%
#export
class PathValidaor:

  def isValid(self,path):
    for x in self.skips:
         if x.search(path):
            return False
    return True

  def __init__(self,  skips = [r"^../../refreshment",r"\.DS_Store$"]):
    self.skips = [re.compile(x) for x in skips]

# %%
valdator = PathValidaor()
valdator.isValid(".DS_Store"),valdator.isValid(".DS_Store_back")
# Out:
# (False, True)

# %%
#hide
aless = Lesson("Intro to Network Flow","flow.mp4")
aless
# Out:
# Intro to Network Flow|0|0|flow.mp4

# %%
#export
def lessonsFromDirectory(root,validator = PathValidaor() ):
    onlyfiles = [f for f in listdir(root) if isfile(join(root, f))]
    valid = [f for f in onlyfiles if validator.isValid (f)]
    valid.sort()
    ret = []
    for x in valid:
        l = Lesson(x,x)
        l.modifyTime = getmtime(join(root,x))
        ret.append(l)
    ret.sort(key=Lesson.sBase)
    return ret

# %%
#hide 
testDir = "../../Cathedral/Reading"
addFiles = lessonsFromDirectory(testDir)
p1Files = []
p2Files = []
for i in range(len(addFiles)):
    if i % 2 == 0:
        p1Files = Lesson.appendUniqueFile(addFiles[i],p1Files)
    if i % 3 == 0:
        p2Files.append(addFiles[i])
p1Files, p2Files
# Out:
# ([SnapByFor.mp4|1|1|SnapByFor.mp4,
#   Fortunately.mp4|2|2|Fortunately.mp4,
#   ThreePart.03.25.mp4|3|3|ThreePart.03.25.mp4,
#   truestory.mp4|4|4|truestory.mp4,
#   MOWiliiams.mp4|5|5|MOWiliiams.mp4,
#   conceptE.mp4|6|6|conceptE.mp4,
#   threepart.4.7.20.mp4|7|7|threepart.4.7.20.mp4,
#   whatbooks.mp4|8|8|whatbooks.mp4,
#   snapwordsmemory..mp4|9|9|snapwordsmemory..mp4,
#   FantasticElasticBrain.mp4|10|10|FantasticElasticBrain.mp4,
#   LetterS.mp4|11|11|LetterS.mp4,
#   ShSound.mp4|12|12|ShSound.mp4,
#   ReadingFromHome.mp4|13|13|ReadingFromHome.mp4,
#   th_sound.mp4|14|14|th_sound.mp4,
#   wletterconcept.mp4|15|15|wletterconcept.mp4,
#   ThreePart.4.30.mp4|16|16|ThreePart.4.30.mp4],
#  [SnapByFor.mp4|1|1|SnapByFor.mp4,
#   LittleBlueTrucj.mp4|0|0|LittleBlueTrucj.mp4,
#   truestory.mp4|4|4|truestory.mp4,
#   ReadAloud.mp4|0|0|ReadAloud.mp4,
#   threepart.4.7.20.mp4|7|7|threepart.4.7.20.mp4,
#   davidtellsjoke.mp4|0|0|davidtellsjoke.mp4,
#   FantasticElasticBrain.mp4|10|10|FantasticElasticBrain.mp4,
#   ThreePart.04.21.mp4|0|0|ThreePart.04.21.mp4,
#   ReadingFromHome.mp4|13|13|ReadingFromHome.mp4,
#   threepart.4.28.mp4|0|0|threepart.4.28.mp4,
#   ThreePart.4.30.mp4|16|16|ThreePart.4.30.mp4])

# %%
#hide
for x in p2Files:
    p1Files = Lesson.appendUniqueFile(x,p1Files)
p1Files
# Out:
# [SnapByFor.mp4|1|1|SnapByFor.mp4,
#  Fortunately.mp4|2|2|Fortunately.mp4,
#  ThreePart.03.25.mp4|3|3|ThreePart.03.25.mp4,
#  truestory.mp4|4|4|truestory.mp4,
#  MOWiliiams.mp4|5|5|MOWiliiams.mp4,
#  conceptE.mp4|6|6|conceptE.mp4,
#  threepart.4.7.20.mp4|7|7|threepart.4.7.20.mp4,
#  whatbooks.mp4|8|8|whatbooks.mp4,
#  snapwordsmemory..mp4|9|9|snapwordsmemory..mp4,
#  FantasticElasticBrain.mp4|10|10|FantasticElasticBrain.mp4,
#  LetterS.mp4|11|11|LetterS.mp4,
#  ShSound.mp4|12|12|ShSound.mp4,
#  ReadingFromHome.mp4|13|13|ReadingFromHome.mp4,
#  th_sound.mp4|14|14|th_sound.mp4,
#  wletterconcept.mp4|15|15|wletterconcept.mp4,
#  ThreePart.4.30.mp4|16|16|ThreePart.4.30.mp4,
#  LittleBlueTrucj.mp4|17|17|LittleBlueTrucj.mp4,
#  ReadAloud.mp4|18|18|ReadAloud.mp4,
#  davidtellsjoke.mp4|19|19|davidtellsjoke.mp4,
#  ThreePart.04.21.mp4|20|20|ThreePart.04.21.mp4,
#  threepart.4.28.mp4|21|21|threepart.4.28.mp4]

# %%
#export
def subjectFromPath(program,subjectName,struct):
    found = False
    p = None
    for x in struct:
        if x.name == program:
            p = x
            found = True
    if not found:
        p = Program(program)
        struct.append(p)

    found = False
    s = None
    for x in p.subjects:
        if x.name == subjectName:
            s = x
            found = True
    if not found:
        s = Subject(subjectName)
        p.subjects.append(s)

    return s

sample = []
testS = subjectFromPath("hogwarts","potions",sample)
testS.toDict()
# Out:
# {'key': 'potions|0|0', 'lessons': []}

# %%
#export
class StudySystem(Record):
    
    def __init__(self, origin="../..", filename="./data/programs.json"):
        super().__init__("StudySystem",1,1)
        self.programs = []
        self.schoolDepth = 4
        self.origin = origin
        self.savePath =  filename

            

    def loadDirectory(self,validator = PathValidaor()):

        schoolDepth = self.schoolDepth
        for root, dirs, files in walk("../.."):
            if validator.isValid(root):
                fPath = fullPathSplit(root)
                #print(fPath,root)
                if len(fPath) == schoolDepth + 1 and fPath[-2] != "Web":
                    less = lessonsFromDirectory(root,validator)
                    prog = fPath[-2]
                    sub = fPath[-1]
                    s = subjectFromPath(prog,sub,self.programs)
                    for x in less:
                        s.addLesson(x)
                
                
    def toDict(self):
        ret = super().toDict()
        ret["programs"] = [x.toDict() for x in self.programs]
        ret["origin"] = self.origin 
        ret["savePath"] = self.savePath 
        return ret
    
    def fromDict(d):
        ret = StudySystem("")
        ret.adjustKey(d["key"])
        ret.programs = [Program.fromDict(x) for x in d["programs"]]
        ret.origin = d["origin"]
        ret.savePath = d["savePath"]
        return ret
    
    def save(self):
        with open(self.savePath, "w") as dataFile:
            json.dump(self.toDict(), dataFile, indent=4, sort_keys=True)
            
    def load(p):
        ret = None
        with open(p) as json_file:
            data = json.load(json_file)
            #print(data)
            ret = StudySystem.fromDict(data)
            
        return ret

# %%
s = Subject("subjectName")
p = Program("")
#p.subjects = Subject.appendUnique(s,p.subjects)
#p.toDict(),s.toDict()
s = Subject("bar")
s
# Out:
# bar; []

# %%
guide = StudySystem()
guide.loadDirectory()
print("done loading")
guide.save()
print("done saving")
eguide = StudySystem.load("./data/programs.json")
for x in eguide.programs:
    print(x.name)
# Out:
# done loading
# done saving
# Cathedral

# %%
print(json.dumps(guide.toDict(), sort_keys=True, indent=4))
# Out:
# {
#     "key": "StudySystem|1|1",
#     "origin": "../..",
#     "programs": [
#         {
#             "key": "Cathedral|0|0",
#             "subjects": [
#                 {
#                     "key": "Reading|0|0",
#                     "lessons": [
#                         {
#                             "key": "SnapByFor.mp4|1|1|SnapByFor.mp4",
#                             "modifyTime": 1585844279.0,
#                             "nextLesson": [],
#                             "requirements": [],
#                             "tags": []
#                         },
#                         {
#                             "key": "ThreePart.03.31.mp4|2|2|ThreePart.03.31.mp4",
#                             "modifyTime": 1585850434.0,
#                             "nextLesson": [],
#                             "requirements": [],
#                             "tags": []
#                         },
#                         {
#                             "key": "Fortunately.mp4|3|3|Fortunately.mp4",
#                             "modifyTime": 1585850467.0,
#                             "nextLesson": [],
#                             "requirements": [],
#                             "tags": []
#                         },
#                         {
#                             "key": "LittleBlueTrucj.mp4|4|4|LittleBlueTrucj.mp4",
#                             "modifyTime": 1585850526.0,
#                             "nextLesson": [],
#                             "requirements": [],
#                             "tags": []
#                         },
#                         {
#                             "key": "ThreePart.03.25.mp4|5|5|ThreePart.03.25.mp4",
#                             "modifyTime": 1585864027.0,
#                             "nextLesson": [],
#                             "requirements": [],
#                             "tags": []
#                         },
#                         {
#                             "key": "5sightwords.mp4|6|6|5sightwords.mp4",
#                             "modifyTime": 1585952952.6611474,
#                             "nextLesson": [],
#                             "requirements": [],
#                             "tags": []
#                         },
#                         {
#                             "key": "truestory.mp4|7|7|truestory.mp4",
#                             "modifyTime": 1585953038.8061655,
#                             "nextLesson": [],
#                             "requirements": [],
#                             "tags": []
#                         },
#                         {
#                             "key": "VisitMusem.mp4|8|8|VisitMusem.mp4",
#                             "modifyTime": 1586106443.530893,
#                             "nextLesson": [],
#                             "requirements": [],
#                             "tags": []
#                         },
#                         {
#                             "key": "MOWiliiams.mp4|9|9|MOWiliiams.mp4",
#                             "modifyTime": 1586106532.537671,
#                             "nextLesson": [],
#                             "requirements": [],
#                             "tags": []
#                         },
#                         {
#                             "key": "ReadAloud.mp4|10|10|ReadAloud.mp4",
#                             "modifyTime": 1586106729.4868186,
#                             "nextLesson": [],
#                             "requirements": [],
#                             "tags": []
#                         },
#                         {
#                             "key": "conceptE.mp4|11|11|conceptE.mp4",
#                             "modifyTime": 1586187519.6956384,
#                             "nextLesson": [],
#                             "requirements": [],
#                             "tags": []
#                         },
#                         {
#                             "key": "LetterEScanegerHunt.mp4|12|12|LetterEScanegerHunt.mp4",
#                             "modifyTime": 1586187575.776107,
#                             "nextLesson": [],
#                             "requirements": [],
#                             "tags": []
#                         },
#                         {
#                             "key": "threepart.4.7.20.mp4|13|13|threepart.4.7.20.mp4",
#                             "modifyTime": 1586274887.8420174,
#                             "nextLesson": [],
#                             "requirements": [],
#                             "tags": []
#                         },
#                         {
#                             "key": "AmosMcGee.mp4|14|14|AmosMcGee.mp4",
#                             "modifyTime": 1586274893.7292764,
#                             "nextLesson": [],
#                             "requirements": [],
#                             "tags": []
#                         },
#                         {
#                             "key": "whatbooks.mp4|15|15|whatbooks.mp4",
#                             "modifyTime": 1586359531.1174757,
#                             "nextLesson": [],
#                             "requirements": [],
#                             "tags": []
#                         },
#                         {
#                             "key": "davidtellsjoke.mp4|16|16|davidtellsjoke.mp4",
#                             "modifyTime": 1586359677.8102448,
#                             "nextLesson": [],
#                             "requirements": [],
#                             "tags": []
#                         },
#                         {
#                             "key": "snapwordsmemory..mp4|17|17|snapwordsmemory..mp4",
#                             "modifyTime": 1586359682.6471636,
#                             "nextLesson": [],
#                             "requirements": [],
#                             "tags": []
#                         },
#                         {
#                             "key": "achairformymother.mp4|18|18|achairformymother.mp4",
#                             "modifyTime": 1586445050.460866,
#                             "nextLesson": [],
#                             "requirements": [],
#                             "tags": []
#                         },
#                         {
#                             "key": "FantasticElasticBrain.mp4|19|19|FantasticElasticBrain.mp4",
#                             "modifyTime": 1586445076.4611552,
#                             "nextLesson": [],
#                             "requirements": [],
#                             "tags": []
#                         },
#                         {
#                             "key":

#                             "nextLesson": [],
#                             "requirements": [],
#                             "tags": []
#                         }
#                     ]
#                 },
#                 {
#                     "key": "Conners|0|0",
#                     "lessons": [
#                         {
#                             "key": "Edward C Class Code.pdf|1|1|Edward C Class Code.pdf",
#                             "modifyTime": 1586106167.1182122,
#                             "nextLesson": [],
#                             "requirements": [],
#                             "tags": []
#                         }
#                     ]
#                 },
#                 {
#                     "key": "Writing|0|0",
#                     "lessons": [
#                         {
#                             "key": "ThreeWishes.mp4|1|1|ThreeWishes.mp4",
#                             "modifyTime": 1585844160.0,
#                             "nextLesson": [],
#                             "requirements": [],
#                             "tags": []
#                         },
#                         {
#                             "key": "WhatDidYouDoWeekend.mp4|2|2|WhatDidYouDoWeekend.mp4",
#                             "modifyTime": 1585850482.0,
#                             "nextLesson": [],
#                             "requirements": [],
#                             "tags": []
#                         },
#                         {
#                             "key": "Laugh.mp4|3|3|Laugh.mp4",
#                             "modifyTime": 1585850902.0,
#                             "nextLesson": [],
#                             "requirements": [],
#                             "tags": []
#                         },
#                         {
#                             "key": "VirtualMuseum.mp4|4|4|VirtualMuseum.mp4",
#                             "modifyTime": 1585851193.0,
#                             "nextLesson": [],
#                             "requirements": [],
#                             "tags": []
#                         },
#                         {
#                             "key": "EnjoyaboutDistanceLearning.mp4|5|5|EnjoyaboutDistanceLearning.mp4",
#                             "modifyTime": 1585851251.0,
#                             "nextLesson": [],
#                             "requirements": [],
#                             "tags": []
#                         },
#                         {
#                             "key": "FeelGood.mp4|6|6|FeelGood.mp4",
#                             "modifyTime": 1585864140.0,
#                             "nextLesson": [],
#                             "requirements": [],
#                             "tags": []
#                         },
#                         {
#                             "key": "VirtualDictitation.mp4|7|7|VirtualDictitation.mp4",
#                             "modifyTime": 1585953136.1337147,
#                             "nextLesson": [],
#                             "requirements": [],
#                             "tags": []
#                         },
#                         {
#                             "key": "TrueStory.mp4|8|8|TrueStory.mp4",
#                             "modifyTime": 1586106302.7909973,
#                             "nextLesson": [],
#                             "requirements": [],
#                             "tags": []
#                         },
#                         {
#                             "key": "NoticeWonder.mp4|9|9|NoticeWonder.mp4",
#                             "modifyTime": 1586106528.1462297,
#                             "nextLesson": [],
#                             "requirements": [],
#                             "tags": []
#                         },
#                         {
#                             "key": "teach.mp4|10|10|teach.mp4",
#                             "modifyTime": 1586359624.9794824,
#                             "nextLesson": [],
#                             "requirements": [],
#                             "tags": []
#                         },
#                         {
#                             "key": "PlannigHowToBook.mp4|11|11|PlannigHowToBook.mp4",
#                             "modifyTime": 1586445010.167947,
#                             "nextLesson": [],
#                             "requirements": [],
#                             "tags": []
#                         },
#                         {
#                             "key": "GK_PC_BK_Box4Lines.pdf|12|12|GK_PC_BK_Box4Lines.pdf",
#                             "modifyTime": 1587525431.384697,
#                             "nextLesson": [],
#                             "requirements": [],
#                             "tags": []
#                         },
#                         {
#                             "key": "SketchingIdeas.mp4|13|13|SketchingIdeas.mp4",
#                             "modifyTime": 1587573368.2172415,
#                             "nextLesson": [],
#                             "requirements": [],
#                             "tags": []
#                         },
#                         {
#                             "key": "HowToDetails.mp4|14|14|HowToDetails.mp4",
#                             "modifyTime": 1587656369.998442,
#                             "nextLesson": [],
#                             "requirements": [],
#                             "tags": []
#                         },
#                         {
#                             "key": "Dictation.mp4|15|15|Dictation.mp4",
#                             "modifyTime": 1587744179.0480406,
#                             "nextLesson": [],
#                             "requirements": [],
#                             "tags": []
#                         },
#                         {
#                             "key": "EditingWorkBook.mp4|16|16|EditingWorkBook.mp4",
#                             "modifyTime": 1587744199.1651008,
#                             "nextLesson": [],
#                             "requirements": [],
#                             "tags": []
#                         },
#                         {
#                             "key": "optionalDictation.mp4|17|17|optionalDictation.mp4",
#                             "modifyTime": 1587744209.488401,
#                             "nextLesson": [],
#                             "requirements": [],
#                             "tags": []
#                         },
#                         {
#                             "key": "CoverBook.mp4|18|18|CoverBook.mp4",
#                             "modifyTime": 1588008602.0896344,
#                             "nextLesson": [],
#                             "requirements": [],
#                             "tags": []
#                         },
#                         {
#                             "key": "howtochoosingrightwords.mp4|19|19|howtochoosingrightwords.mp4",
#                             "modifyTime": 1588205334.599958,
#                             "nextLesson": [],
#                             "requirements": [],
#                             "tags": []
#                         },
#                         {
#                             "key": "howtolistentoreaders.mp4|20|20|howtolistentoreaders.mp4",
#                             "modifyTime": 1588205810.1641917,
#                             "nextLesson": [],
#                             "requirements": [],
#                             "tags": []
#                         },
#                         {
#                             "key": "workOnHowTo.mp4|21|21|workOnHowTo.mp4",
#                             "modifyTime": 1588261797.4888272,
#                             "nextLesson": [],
#                             "requirements": [],
#                             "tags": []
#                         },
#                         {
#                             "key": "letterConcepty.mp4|22|22|letterConcepty.mp4",
#                             "modifyTime": 1588605617.3939006,
#                             "nextLesson": [],
#                             "requirements": [],
#                             "tags": []
#                         },
#                         {
#                             "key": "imaging.seesaw.me.png|23|23|imaging.seesaw.me.png",
#                             "modifyTime": 1588605679.964226,
#                             "nextLesson": [],
#                             "requirements": [],
#                             "tags": []
#                         },
#                         {
#                             "key": "bestguessspelling.mp4|24|24|bestguessspelling.mp4",
#                             "modifyTime": 1588691977.6971543,
#                             "nextLesson": [],
#                             "requirements": [],
#                             "tags": []
#                         }
#                     ]
#                 }
#             ]
#         }
#     ],
#     "savePath": "./data/programs.json"
# }

# %%
#hide
from nbdev.export import *
notebook2script()
# Out:
# Converted 00_core.ipynb.
# Converted 01_StudySystem.ipynb.
# Converted 02_DataMunge.ipynb.
# Converted 03_web.ipynb.
# Converted index.ipynb.
